# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
from google.colab import drive

# %%
pd.read_csv("/content/drive/MyDrive/441_Lecture 1/spotify_cut.csv")
# Out:
#       Position              Track Name           Artist  Streams  \
# 0            1   ReggaetnLentoBailemos             CNCO    19272
# 1            2                Chantaje          Shakira    19270
# 2            3      OtraVezfeatJBalvin       ZionLennox    15761
# 3            4               VentePaCa      RickyMartin    14954
# 4            5                  Safari          JBalvin    14269
# ...        ...                     ...              ...      ...
# 4079        80        EncantadoraRemix           Yandel     2899
# 4080        81             StressedOut  TwentyOnePilots     2839
# 4081        82    ThisIsWhatYouCameFor     CalvinHarris     2810
# 4082        83         HastaelAmanecer         NickyJam     2810
# 4083        84  CorazonDeSedafeatOzuna          Klasico     2805
#
#                                                     URL     Date Region
# 0     https://open.spotify.com/track/3AEZUABDXNtecAO...   1/1/17     ec
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/441_Lecture 1/spotify_cut.csv")

# %%
df
# Out:
#       Position              Track Name           Artist  Streams  \
# 0            1   ReggaetnLentoBailemos             CNCO    19272
# 1            2                Chantaje          Shakira    19270
# 2            3      OtraVezfeatJBalvin       ZionLennox    15761
# 3            4               VentePaCa      RickyMartin    14954
# 4            5                  Safari          JBalvin    14269
# ...        ...                     ...              ...      ...
# 4079        80        EncantadoraRemix           Yandel     2899
# 4080        81             StressedOut  TwentyOnePilots     2839
# 4081        82    ThisIsWhatYouCameFor     CalvinHarris     2810
# 4082        83         HastaelAmanecer         NickyJam     2810
# 4083        84  CorazonDeSedafeatOzuna          Klasico     2805
#
#                                                     URL     Date Region
# 0     https://open.spotify.com/track/3AEZUABDXNtecAO...   1/1/17     ec
# ...

# %%
import matplotlib.pyplot as plt

# %%
#Creating a Bar Graph
x_axis = df['Position']
y_axis = df['Streams']

plt.bar(x_axis, y_axis)
plt.title('Spotify Dataset')
plt.xlabel('Position of Song')
plt.ylabel('Number of Streams')
plt.show()

# %% [markdown]
# The graph depicts the relationship between the position of the song on the leaderboard and the number of streams. We can see that there is a large difference between the number of streams of the song at position 1 with the number of streams for the song at the last position.
